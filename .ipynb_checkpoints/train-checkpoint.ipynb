# %%
import os
import threading
import time

import cv2
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import utils

import vrep
from hexapod import Hexapod, connect

from image_train import ImageTrain
from image_train import train_set_percentage
from image_train import test_robot

# %%
train = ImageTrain()

# %%
label_row_1, data_row_1 = train.get_data('./gen_image/')
# Out:
# {=>...............................................................................} 1%
# {==>..............................................................................} 3%
# {====>............................................................................} 5%
# {=====>...........................................................................} 6%
# {======>..........................................................................} 7%
# {=======>.........................................................................} 9%
# {========>........................................................................} 10%
# {=========>.......................................................................} 12%
# {===========>.....................................................................} 13%
# {============>....................................................................} 15%
# {=============>...................................................................} 16%
# {==============>..................................................................} 18%
# {================>................................................................} 19%
# {=================>...............................................................} 21%
# {==================>..............................................................} 22%
# {===================>.............................................................} 23%
# {====================>............................................................} 25%
# {=====================>...........................................................} 26%
# {======================>..........................................................} 28%
# {=======================>.........................................................} 29%
# {=========================>.......................................................} 31%
# {==========================>......................................................} 32%
# {===========================>.....................................................} 34%
# {============================>....................................................} 35%
# {=============================>...................................................} 36%
# {==============================>..................................................} 38%
# {===============================>.................................................} 39%
# {================================>................................................} 40%
# {=================================>...............................................} 42%
# {==================================>..............................................} 43%
# {===================================>.............................................} 44%
# {====================================>............................................} 45%
# {======================================>..........................................} 47%
# {=======================================>.........................................} 49%
# {========================================>........................................} 50%
# {=========================================>.......................................} 51%
# {==========================================>......................................} 53%
# {===========================================>.....................................} 54%
# {============================================>....................................} 55%
# {=============================================>...................................} 57%
# {==============================================>..................................} 58%
# {================================================>................................} 59%
# {=================================================>...............................} 61%
# {==================================================>..............................} 62%
# {===================================================>.............................} 64%
# {=====================================================>...........................} 66%
# {======================================================>..........................} 67%
# {=======================================================>.........................} 69%
# {========================================================>........................} 70%
# {=========================================================>.......................} 72%
# {===========================================================>.....................} 73%
# {============================================================>....................} 75%
# {=============================================================>...................} 77%
# {==============================================================>..................} 78%
# {================================================================>................} 79%
# {=================================================================>...............} 81%
# {==================================================================>..............} 82%
# {===================================================================>.............} 84%
# {====================================================================>............} 85%
# {======================================================================>..........} 87%
# {=======================================================================>.........} 89%
# {========================================================================>........} 90%
# {=========================================================================>.......} 92%
# {==========================================================================>......} 93%
# {============================================================================>....} 95%
# {=============================================================================>...} 96%
# {==============================================================================>..} 98%
# {===============================================================================>.} 99%
# {================================================================================>} 100%

# %%
label_tmp_1 = np.argmax(label_row_1, axis=1)
label_tmp_1[np.where(label_tmp_1 == 2)[0]]=1
label_tmp_1[np.where(label_tmp_1 == 3)[0]]=1
label_tmp_1[np.where(label_tmp_1 == 5)[0]]=1
label_tmp_1[np.where(label_tmp_1 == 6)[0]]=1

# %%
def rechoice_j(label, data=None, num=None,shuffle=True):
    assert(num!=None)
#     label = np.argmax(label, axis=1)
    con_list=[]
    data_list=[0,1,2,3,4,5,6]
    for i,element in enumerate(num):
        con_list.append(np.random.choice(np.where(label == data_list[i])[0],element))
    result = np.concatenate(con_list)
    if shuffle:
        np.random.shuffle(result)
    label = label[result]
#     label = utils.to_categorical(label, num_classes=num_classes)
    if data is None:
        return label
    data = data[result]
    return label, data

# %%
data_tmp_1=data
train_label_1,train_data_1=rechoice_j(label_tmp_1,data_tmp_1,[6600,6600])
train_label_1=utils.to_categorical(train_label_1, num_classes=7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-88be7e9764d2> in <module>
# ----> 1 data_tmp_1=data
#       2 train_label_1,train_data_1=rechoice_j(label_tmp_1,data_tmp_1,[6600,6600])
#
# NameError: name 'data' is not defined

# %%
train_set_percentage(train_label_1)
# Out:
# 2:0 3:0 5:0 6:0 0:6601 1:13442 4:0

# %%
model=train.build_model(train_data_1,train_label_1)
model.fit(train_data, train_label, batch_size=32, epochs=20,
                  validation_split=0.3)
# Out:
# Train on 9240 samples, validate on 3960 samples
# Epoch 1/20
# 9240/9240 [==============================] - 17s 2ms/step - loss: 1.5750 - mean_absolute_error: 0.3383 - mean_squared_error: 0.2117 - acc: 0.7392 - val_loss: 0.3241 - val_mean_absolute_error: 0.2375 - val_mean_squared_error: 0.0953 - val_acc: 0.9056
# Epoch 2/20
# 9240/9240 [==============================] - 10s 1ms/step - loss: 0.3423 - mean_absolute_error: 0.2183 - mean_squared_error: 0.1046 - acc: 0.8575 - val_loss: 0.2230 - val_mean_absolute_error: 0.1510 - val_mean_squared_error: 0.0598 - val_acc: 0.9106
# Epoch 3/20
# 9240/9240 [==============================] - 10s 1ms/step - loss: 0.2980 - mean_absolute_error: 0.1915 - mean_squared_error: 0.0891 - acc: 0.8784 - val_loss: 0.2018 - val_mean_absolute_error: 0.1380 - val_mean_squared_error: 0.0515 - val_acc: 0.9197
# Epoch 4/20
# 9240/9240 [==============================] - 10s 1ms/step - loss: 0.2575 - mean_absolute_error: 0.1644 - mean_squared_error: 0.0751 - acc: 0.8984 - val_loss: 0.1741 - val_mean_absolute_error: 0.1085 - val_mean_squared_error: 0.0490 - val_acc: 0.9328
# Epoch 5/20
# 9240/9240 [==============================] - 10s 1ms/step - loss: 0.2174 - mean_absolute_error: 0.1387 - mean_squared_error: 0.0614 - acc: 0.9207 - val_loss: 0.1419 - val_mean_absolute_error: 0.0841 - val_mean_squared_error: 0.0386 - val_acc: 0.9505
# Epoch 6/20
# 9240/9240 [==============================] - 11s 1ms/step - loss: 0.1923 - mean_absolute_error: 0.1206 - mean_squared_error: 0.0529 - acc: 0.9306 - val_loss: 0.5047 - val_mean_absolute_error: 0.1849 - val_mean_squared_error: 0.1345 - val_acc: 0.8371
# Epoch 7/20
# 9240/9240 [==============================] - 11s 1ms/step - loss: 0.1693 - mean_absolute_error: 0.1054 - mean_squared_error: 0.0463 - acc: 0.9425 - val_loss: 0.1694 - val_mean_absolute_error: 0.1015 - val_mean_squared_error: 0.0487 - val_acc: 0.9346
# Epoch 8/20
# 9240/9240 [==============================] - 11s 1ms/step - loss: 0.1615 - mean_absolute_error: 0.1000 - mean_squared_error: 0.0437 - acc: 0.9448 - val_loss: 0.1044 - val_mean_absolute_error: 0.0658 - val_mean_squared_error: 0.0254 - val_acc: 0.9667n_absol - ETA: 0s - loss: 0.1608 - mean_absolute_error: 0.0998 - mean_squared_error: 0.0436 - acc: 0.
# Epoch 9/20
# 9240/9240 [==============================] - 11s 1ms/step - loss: 0.1451 - mean_absolute_error: 0.0874 - mean_squared_error: 0.0373 - acc: 0.9545 - val_loss: 0.0865 - val_mean_absolute_error: 0.0528 - val_mean_squared_error: 0.0191 - val_acc: 0.9788
# Epoch 10/20
# 9240/9240 [==============================] - 11s 1ms/step - loss: 0.1096 - mean_absolute_error: 0.0663 - mean_squared_error: 0.0281 - acc: 0.9663 - val_loss: 0.0799 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0169 - val_acc: 0.9811

# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-cb361ba3b9e3> in <module>
# ----> 1 test_robot('turn_straight_cla.h5')
#
# TypeError: test_robot() takes 0 positional arguments but 1 was given

# %%
_,data_tmp_2=rechoice_j(label_tmp_1,data_row_1,[0,13000])
label_tmp_2=np.zeros((data_tmp_2.shape[0],2))
label_tmp_2[:,1]=1

# %%
label_row_3,data_row_3=train.get_data_range('./image/archive-ahead-train/',987,1000)
label_tmp_3=np.zeros((data_row_3.shape[0],2))
label_tmp_3[:,0]=1

train_label_2_row = np.concatenate([label_tmp_2,label_tmp_3])
train_data_2_row = np.concatenate([data_tmp_2,data_row_3])

print(train_label_2_row.shape,train_data_2_row.shape)
# Out:
# {=============================================================================>...} 96%
# {==>..............................................................................} 2%
# {===========>.....................................................................} 14%
# {===============================>.................................................} 39%
# {================================================================================>} 100%
# (15372, 2) (15372, 64, 64, 1)

# %%
t_label= np.argmax(train_label_2_row, axis=1)
train_label_2_tmp,train_data_2=rechoice_j(t_label,train_data_2_row,[2300,2300])
train_label_2 = utils.to_categorical(train_label_2_tmp, num_classes=2)

model_2=train.build_model(train_data_2,train_label_2)
history=model_2.fit(train_data_2,train_label_2,batch_size=32, epochs=20,
                  validation_split=0.3)
# Out:
# Train on 3220 samples, validate on 1380 samples
# Epoch 1/20
# 3220/3220 [==============================] - 7s 2ms/step - loss: 5.1876 - mean_absolute_error: 0.4210 - mean_squared_error: 0.3894 - acc: 0.5882 - val_loss: 0.3772 - val_mean_absolute_error: 0.2610 - val_mean_squared_error: 0.1096 - val_acc: 0.9072
# Epoch 2/20
# 3220/3220 [==============================] - 2s 504us/step - loss: 0.3865 - mean_absolute_error: 0.2524 - mean_squared_error: 0.1201 - acc: 0.8419 - val_loss: 0.3131 - val_mean_absolute_error: 0.2082 - val_mean_squared_error: 0.0883 - val_acc: 0.9029
# Epoch 3/20
# 3220/3220 [==============================] - 2s 510us/step - loss: 0.3253 - mean_absolute_error: 0.2109 - mean_squared_error: 0.0987 - acc: 0.8745 - val_loss: 0.2313 - val_mean_absolute_error: 0.1697 - val_mean_squared_error: 0.0651 - val_acc: 0.9283
# Epoch 4/20
# 3220/3220 [==============================] - 2s 512us/step - loss: 0.3468 - mean_absolute_error: 0.2359 - mean_squared_error: 0.1115 - acc: 0.8463 - val_loss: 0.2759 - val_mean_absolute_error: 0.1624 - val_mean_squared_error: 0.0822 - val_acc: 0.8913
# Epoch 5/20
# 3220/3220 [==============================] - 2s 529us/step - loss: 0.3253 - mean_absolute_error: 0.1980 - mean_squared_error: 0.0985 - acc: 0.8804 - val_loss: 0.4338 - val_mean_absolute_error: 0.3166 - val_mean_squared_error: 0.1525 - val_acc: 0.8862
# Epoch 6/20
# 3220/3220 [==============================] - 2s 524us/step - loss: 0.4220 - mean_absolute_error: 0.3057 - mean_squared_error: 0.1495 - acc: 0.8925 - val_loss: 0.3849 - val_mean_absolute_error: 0.2809 - val_mean_squared_error: 0.1350 - val_acc: 0.9391
# Epoch 7/20
# 3220/3220 [==============================] - 2s 516us/step - loss: 0.4122 - mean_absolute_error: 0.2993 - mean_squared_error: 0.1447 - acc: 0.9031 - val_loss: 0.3733 - val_mean_absolute_error: 0.2733 - val_mean_squared_error: 0.1300 - val_acc: 0.9355
# Epoch 8/20
# 3220/3220 [==============================] - 2s 520us/step - loss: 0.4053 - mean_absolute_error: 0.2959 - mean_squared_error: 0.1415 - acc: 0.9019 - val_loss: 0.3937 - val_mean_absolute_error: 0.2913 - val_mean_squared_error: 0.1359 - val_acc: 0.9203
# Epoch 9/20
