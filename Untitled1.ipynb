# %%
import tensorflow as tf
tf.VERSION
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-cdbbd254a368> in <module>
# ----> 1 import tensorflow as tf
#       2 tf.VERSION
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ----------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.6
# anaconda-project                   0.8.2
# appdirs                            1.4.3
# asn1crypto                         0.24.0
# astroid                            2.2.5
# astropy                            3.1
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Automat                            0.7.0
# autopep8                           1.4.3
# Babel                              2.6.0
# backcall                           0.1.0
# backports.os                       0.1.1
# backports.shutil-get-terminal-size 1.0.0
# bcrypt                             3.1.6
# beautifulsoup4                     4.6.3
# bitarray                           0.8.3
# bkcharts                           0.2
# blaze                              0.11.3
# ...
